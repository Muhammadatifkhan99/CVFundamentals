# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
im = np.arange(256)
im = im[np.newaxis,:]
im = np.repeat(im,100,axis=0)
plt.imshow(im,cmap='gray')

# %% [markdown]
# # Processing Grayscale images

# %%
im = plt.imread(r'./images/albert-einstein_gray.jpg')

# %%
type(im)
# Out:
# numpy.ndarray

# %%
im.shape
# Out:
# (949, 728)

# %%
im.dtype
# Out:
# dtype('uint8')

# %%
plt.imshow(im,cmap='gray')

# %%
im
# Out:
# array([[85, 85, 85, ..., 62, 62, 62],
#        [85, 85, 85, ..., 64, 65, 64],
#        [85, 85, 85, ..., 59, 59, 58],
#        ...,
#        [36, 42, 42, ..., 36, 42, 47],
#        [29, 37, 37, ..., 36, 43, 44],
#        [33, 40, 37, ..., 35, 43, 42]], shape=(949, 728), dtype=uint8)

# %%
im[23,300]
# Out:
# np.uint8(70)

# %%
im[23:100,40:100] = 255
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 im[23:100,40:100] = 255
#
# ValueError: assignment destination is read-only

# %%
im[23,100] = 200
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 im[23,100] = 200
#
# ValueError: assignment destination is read-only

# %%
im2 = im.copy()

# %%
im2[23,100] = 200

# %%
im2[23:100,40:100] = 255

# %%
plt.imshow(im2,cmap='gray')

# %%
im2[300:400,40:100] = 0

# %%
plt.imshow(im2,cmap='gray')

# %%
# Quiz Solution
im = plt.imread(r'./images/albert-einstein_gray.jpg')
im3 = im.copy()

im3[330:430,300:400] = 255 #for left eye
im3[330:430,440:540] = 255 #for right eye

plt.imshow(im3, cmap='gray')

# %%
plt.imsave(r'./images/albert-einstein_gray_modified_patch.jpg',im2,cmap='gray')

# %%
 pip install opencv-contrib-python
# Out:
# Collecting opencv-contrib-python
#   Downloading opencv_contrib_python-4.13.0.92-cp37-abi3-manylinux_2_28_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=2 in /home/atif/Desktop/ComputerVision/CVCourse/.venv/lib/python3.12/site-packages (from opencv-contrib-python) (2.4.4)
# Downloading opencv_contrib_python-4.13.0.92-cp37-abi3-manylinux_2_28_x86_64.whl (79.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.2/79.2 MB 892.3 kB/s  0:01:41m0:00:0100:03
# Installing collected packages: opencv-contrib-python
# Successfully installed opencv-contrib-python-4.13.0.92
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: /home/atif/Desktop/ComputerVision/CVCourse/.venv/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Grayscale Images in OpenCV

# %%
import cv2

# %%
img = cv2.imread(r'./images/albert-einstein_gray.jpg',cv2.IMREAD_GRAYSCALE)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
img.shape
# Out:
# (949, 728)

# %%
img[23,100] = 0 #images read by opencv can be modified using this method by this is not allowed in matplotlib

# %%
plt.imshow(img,cmap='gray')

# %%
cv2.imshow('Gray',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Warning: Ignoring XDG_SESSION_TYPE=wayland on Gnome. Use QT_QPA_PLATFORM=wayland to run on Wayland anyway.
# QFontDatabase: Cannot find font directory /home/atif/Desktop/ComputerVision/CVCourse/.venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/atif/Desktop/ComputerVision/CVCourse/.venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/atif/Desktop/ComputerVision/CVCourse/.venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/atif/Desktop/ComputerVision/CVCourse/.venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/atif/Desktop/ComputerVision/CVCourse/.venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.

# %%
img[500:700,500:600] = 255

# %%
cv2.imshow('Gray',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imwrite(r'./albert-einstein_gray_opencvffffffff.jpg',img)
# Out:
# True

# %% [markdown]
# # RGB Images

# %%
cim = plt.imread(r'tulips.jpg')

# %%
plt.imshow(cim)

# %%
cim.shape
# Out:
# (638, 640, 3)

# %%
type(cim)
# Out:
# numpy.ndarray

# %%
cim.dtype
# Out:
# dtype('uint8')

# %%
# Solution to Quiz 03_06
rgb = np.zeros((100,150,3), dtype='uint8')
rgb[:,0:50,0] = 255 # red
rgb[:,50:100,1] = 255 #green
rgb[:,100:150,2] = 255 #blue
 
plt.imshow(rgb)

# %%
cv2.imshow('RGB',rgb)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # OpenCV reads as BGR

# %%
cim = cv2.imread(r'tulips.jpg')
cim = cim[:,:,::-1]
R = cim[:,:,0]
G = cim[:,:,1]
B = cim[:,:,2]

# %%
plt.figure(1)

plt.subplot(231)
plt.imshow(cim)
plt.xticks([])
plt.yticks([])

plt.subplot(232)
plt.imshow(cim)
plt.xticks([])
plt.yticks([])

plt.subplot(233)
plt.imshow(cim)
plt.xticks([])
plt.yticks([])

plt.subplot(234)
plt.imshow(R,cmap='gray')
plt.xticks([])
plt.yticks([])
plt.title('Red')

plt.subplot(235)
plt.imshow(G,cmap='gray')
plt.xticks([])
plt.yticks([])
plt.title('Green')

plt.subplot(236)
plt.imshow(B,cmap='gray')
plt.xticks([])
plt.yticks([])
plt.title('Blue')
plt.show()

# %%
R[100:400,100:400] = 100
G[100:400,100:400] = 50
B[100:400,100:400] = 70
cim[:,:,0] = R
cim[:,:,1] = G
cim[:,:,2] = B

plt.figure(1)

plt.subplot(231)
plt.imshow(cim)
plt.xticks([])
plt.yticks([])

plt.subplot(232)
plt.imshow(cim)
plt.xticks([])
plt.yticks([])

plt.subplot(233)
plt.imshow(cim)
plt.xticks([])
plt.yticks([])

plt.subplot(234)
plt.imshow(R,cmap='gray')
plt.xticks([])
plt.yticks([])
plt.title('Red')

plt.subplot(235)
plt.imshow(G,cmap='gray')
plt.xticks([])
plt.yticks([])
plt.title('Green')

plt.subplot(236)
plt.imshow(B,cmap='gray')
plt.xticks([])
plt.yticks([])
plt.title('Blue')
plt.show()

# %% [markdown]
# # RGB to HSV conversion

# %%
def f_rgb_to_hsv(r, g, b,scaleFactor): 
    r, g, b = r / 255.0, g / 255.0, b / 255.0
    cmax = max(r, g, b)    # maximum of r, g, b 
    cmin = min(r, g, b)    # minimum of r, g, b 
    diff = cmax-cmin       # diff of cmax and cmin. 
    if cmax == cmin:  
        h = 0
    elif cmax == r:  
        h = (60 * ((g - b) / diff) + 0) % 360
    elif cmax == g: 
        h = (60 * ((b - r) / diff) + 120) % 360
    elif cmax == b: 
        h = (60 * ((r - g) / diff) + 240) % 360
   
    if h < 0:
        h = h + 360
    if cmax == 0: 
        s = 0
    else: 
        s = (diff / cmax) * scaleFactor
    v = cmax * scaleFactor
    return h, s, v

# %%
print(f_rgb_to_hsv(100,200,50,100))
# Out:
# (100.0, 75.0, 78.43137254901961)

# %%
im = cv2.imread(r'tulips.jpg')

# %%
HsvIm = cv2.cvtColor(im,cv2.COLOR_BGR2HSV)
cv2.cvtColor(im,cv2.COLOR_HSV2BGR)

# %%
type(HsvIm)
# Out:
# numpy.ndarray

# %%
HsvIm.shape
# Out:
# (638, 640, 3)

# %%
img = cv2.imread(r'tulips.jpg')

# %%
plt.imshow(img[:,:,::-1])

# %%
hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)

# %%
lr = np.array([0,120,70])
ur = np.array([8,255,255])
mask1 = cv2.inRange(hsv,lr,ur)

# %%
type(mask1)
# Out:
# numpy.ndarray

# %%
mask1.dtype
# Out:
# dtype('uint8')

# %%
mask1.shape
# Out:
# (638, 640)

# %%
mask1.max()
# Out:
# 255

# %%
mask1.min()
# Out:
# 0

# %%
lr = np.array([170,120,70])
ur = np.array([180,255,255])
mask2 = cv2.inRange(hsv,lr,ur)

# %%
np.unique(mask2)
# Out:
# array([  0, 255], dtype=uint8)

# %%
np.unique(mask1)
# Out:
# array([  0, 255], dtype=uint8)

# %%
mask = mask1 | mask2

# %%
np.unique(mask)
# Out:
# array([  0, 255], dtype=uint8)

# %%
res = cv2.bitwise_and(img,img,mask=mask)

# %%
plt.figure(1)
plt.subplot(121)
plt.imshow(img[:,:,::-1])
plt.subplot(122)
plt.imshow(res[:,:,::-1])
plt.show()

# %%
# solution to quiz
lr = np.array([20,100,100])
ur = np.array([30,255,255])
yellow_mask = cv2.inRange(hsv,lr,ur)
res = cv2.bitwise_and(img,img,mask=yellow_mask)

# %%
plt.figure(1)
plt.subplot(121)
plt.imshow(img[:,:,::-1])
plt.subplot(122)
plt.imshow(res[:,:,::-1])
plt.show()

# %% [markdown]
# #End of Notebook
