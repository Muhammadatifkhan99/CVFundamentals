# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
im = np.arange(256)
im = im[np.newaxis,:]
im = np.repeat(im,100,axis = 0)
plt.imshow(im,cmap='grey')

# %%
im
# Out:
# array([[  0,   1,   2, ..., 253, 254, 255],
#        [  0,   1,   2, ..., 253, 254, 255],
#        [  0,   1,   2, ..., 253, 254, 255],
#        ...,
#        [  0,   1,   2, ..., 253, 254, 255],
#        [  0,   1,   2, ..., 253, 254, 255],
#        [  0,   1,   2, ..., 253, 254, 255]], shape=(100, 256))

# %%
im.shape
# Out:
# (100, 256)

# %%
im = im[np.newaxis,:]

# %%
im.shape
# Out:
# (1, 100, 256)

# %%
im = np.repeat(im,10,axis = 0)

# %%
im.shape
# Out:
# (10, 100, 256)

# %%
im
# Out:
# array([[[  0,   1,   2, ..., 253, 254, 255],
#         [  0,   1,   2, ..., 253, 254, 255],
#         [  0,   1,   2, ..., 253, 254, 255],
#         ...,
#         [  0,   1,   2, ..., 253, 254, 255],
#         [  0,   1,   2, ..., 253, 254, 255],
#         [  0,   1,   2, ..., 253, 254, 255]],
#
#        [[  0,   1,   2, ..., 253, 254, 255],
#         [  0,   1,   2, ..., 253, 254, 255],
#         [  0,   1,   2, ..., 253, 254, 255],
#         ...,
#         [  0,   1,   2, ..., 253, 254, 255],
#         [  0,   1,   2, ..., 253, 254, 255],
#         [  0,   1,   2, ..., 253, 254, 255]],
#
#        [[  0,   1,   2, ..., 253, 254, 255],
#         [  0,   1,   2, ..., 253, 254, 255],
#         [  0,   1,   2, ..., 253, 254, 255],
#         ...,
#         [  0,   1,   2, ..., 253, 254, 255],
#         [  0,   1,   2, ..., 253, 254, 255],
#         [  0,   1,   2, ..., 253, 254, 255]],
#
#        ...,
#
#        [[  0,   1,   2, ..., 253, 254, 255],
# ...

# %%
plt.imshow(im[0],cmap='grey')
